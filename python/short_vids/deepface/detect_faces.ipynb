# %%
from PIL import Image
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
# Define the file paths for the photos 
photo_gallery_path = "C:/projects/tutorials/python/photos"

image_1_path = f"{photo_gallery_path}/image_1.jpg"
image_2_path = f"{photo_gallery_path}/image_2.jpg"
image_3_path = f"{photo_gallery_path}/image_3.jpg"
image_4_path = f"{photo_gallery_path}/image_4.jpg"

# %%
# Show the images 
image_1 = Image.open(image_1_path)
image_2 = Image.open(image_2_path)
image_3 = Image.open(image_3_path)
image_4 = Image.open(image_4_path)

plt.imshow(image_1)

# %%
plt.imshow(image_2)

# %%
plt.imshow(image_3)

# %%
plt.imshow(image_4)

# %%
face_detection_check = DeepFace.extract_faces(img_path=image_2_path)
face_detection_check
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 face_detection_check = DeepFace.extract_faces(img_path=image_2_path)
#       2 face_detection_check
#
# File c:\Users\steph\anaconda3\envs\python_tutorials_venv\lib\site-packages\deepface\DeepFace.py:468, in extract_faces(img_path, target_size, detector_backend, enforce_detection, align, expand_percentage, grayscale)
#     424 def extract_faces(
#     425     img_path: Union[str, np.ndarray],
#     426     target_size: Optional[Tuple[int, int]] = (224, 224),
#    (...)
#     431     grayscale: bool = False,
#     432 ) -> List[Dict[str, Any]]:
#     433     """
#     434     Extract faces from a given image
#     435
#    (...)
#     465         - "confidence" (float): The confidence score associated with the detected face.
#     466     """
# --> 468     return detection.extract_faces(
# ...

# %%
same_person_check = DeepFace.verify(img1_path = image_1_path, img2_path = image_4_path, enforce_detection=False)
same_person_check['verified']
# Out:
# False
